# %%
## import Pandas
import pandas as pd

# %%
## Upload CSV 
## Read as dataframe
## assign dataframe to monkeys

df = pd.read_csv("medicallab_primate_data.csv")
monkeys = pd.read_csv("medicallab_primate_data.csv")

# %%
## display "monkeys" data
monkeys
# Out:
#                   Common Name                 Taxon     Class     Order  \
# 0                  Chimpanzee       Pan troglodytes  Mammalia  Primates
# 1                  Chimpanzee       Pan troglodytes  Mammalia  Primates
# 2       Brown-mantled tamarin  Saguinus fuscicollis  Mammalia  Primates
# 3          Moustached tamarin       Saguinus mystax  Mammalia  Primates
# 4    Common Squirrel Monkeys*      Saimiri sciureus  Mammalia  Primates
# ..                        ...                   ...       ...       ...
# 905     Wedge-capped capuchin       Cebus olivaceus  Mammalia  Primates
# 906       Crab-eating macaque   Macaca fascicularis  Mammalia  Primates
# 907       Crab-eating macaque   Macaca fascicularis  Mammalia  Primates
# 908       Crab-eating macaque   Macaca fascicularis  Mammalia  Primates
# 909       Crab-eating macaque   Macaca fascicularis  Mammalia  Primates
#
#               Family     Genus  Year App.     ICUN Status Importer Exporter  \
# ...

# %%
df['Common Name'].unique()
# Out:
# array(['Chimpanzee', 'Brown-mantled tamarin', 'Moustached tamarin',
#        'Common Squirrel Monkeys*', 'Rhesus macaque',
#        'Buffy-headed marmoset', 'Western Pygmy Marmoset', 'Black lemur',
#        'Black-and-white ruffed lemur', 'White-lipped tamarin', 'Macaques',
#        'Crab-eating macaque', 'Japanese macaque',
#        'Southern pig-tailed macaque', 'Celebes crested macaque',
#        'Olive baboon', 'Yellow baboon', 'Primates', 'Golden lion tamarin',
#        'Common brown lemur', 'Three-striped night monkey',
#        'Common marmoset', 'Hamadryas baboon', 'Chacma baboon',
#        "Goeldi's marmoset", 'Baboons', 'Brown greater galago',
#        'Gray mouse lemur', "Coquerel's giant mouse lemur",
#        'Bornean orangutan', "Verreaux's sifaka", 'Mongoose lemur',
#        'Eastern lesser bamboo lemur', 'Silvery Marmoset', 'Grivet',
#        'Red slender loris', 'Mantled Howler Monkey', 'Diana monkey',
# ...

# %%
## Get details
monkeys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Common Name                 910 non-null    object
#  1   Taxon                       910 non-null    object
#  2   Class                       910 non-null    object
#  3   Order                       910 non-null    object
#  4   Family                      904 non-null    object
#  5   Genus                       904 non-null    object
#  6   Year                        910 non-null    int64
#  7   App.                        910 non-null    object
#  8   ICUN Status                 892 non-null    object
#  9   Importer                    910 non-null    object
#  10  Exporter                    910 non-null    object
#  11  Origin                      139 non-null    object
#  12  Importer reported quantity  473 non-null    float64
# ...

# %%
## Summary Stats
## Find "Importer reported quantity states" for all monkeys

df["Importer reported quantity"].describe()
# Out:
# count      473.000000
# mean       466.649049
# std       1212.272283
# min          1.000000
# 25%         16.000000
# 50%         80.000000
# 75%        270.000000
# max      15010.000000
# Name: Importer reported quantity, dtype: float64

# %%
## Find Top Years Imported for all primates
df.sort_values(by=["Importer reported quantity"], ascending = False)
# Out:
#                Common Name                Taxon     Class     Order  \
# 898    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 744    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 831    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 722    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 871    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# ..                     ...                  ...       ...       ...
# 905  Wedge-capped capuchin      Cebus olivaceus  Mammalia  Primates
# 906    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 907    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 908    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 909    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
#
#               Family   Genus  Year App.    ICUN Status Importer Exporter  \
# 898  Cercopithecidae  Macaca  2018   II     Vulnerable       US       CN
# ...

# %%
## Sum of columns
df.sum(axis=0)
# Out:
# Common Name                   ChimpanzeeChimpanzeeBrown-mantled tamarinMoust...
# Taxon                         Pan troglodytesPan troglodytesSaguinus fuscico...
# Class                         MammaliaMammaliaMammaliaMammaliaMammaliaMammal...
# Order                         PrimatesPrimatesPrimatesPrimatesPrimatesPrimat...
# Year                                                                    1817177
# App.                          IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII...
# Importer                      USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Exporter                      FRCAPEPECAPECAPEPEFRFRFRDEGBPEPEPEPEGTGYPEMYID...
# Importer reported quantity                                               220725
# Exporter reported quantity                                               184603
# Term                          liveliveliveliveliveliveliveliveliveliveliveli...
# Unit                                                                          0
# ...

# %%
df['Common Name'].value_counts()
# Out:
# Crab-eating macaque      310
# Rhesus macaque            89
# Grivet                    53
# Common marmoset           40
# Olive baboon              35
#                         ...
# Lion-tailed macaque        1
# Golden bamboo lemur        1
# Woolly monkeys             1
# Agile gibbon               1
# Mantled Howler Monkey      1
# Name: Common Name, Length: 95, dtype: int64

# %%
## isolate years for macaques:

filter1 = monkeys["Year"] >= 2013
filter2 = monkeys["Year"] <= 2021

## Filter it

monkeys[filter1 & filter2]
monkeys1320 = monkeys[filter1 & filter2]

# %%
monkeys1320
# Out:
#                Common Name                Taxon     Class     Order  \
# 829           Green monkey  Chlorocebus sabaeus  Mammalia  Primates
# 830           Green monkey  Chlorocebus sabaeus  Mammalia  Primates
# 831    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 832    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 833    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# ..                     ...                  ...       ...       ...
# 905  Wedge-capped capuchin      Cebus olivaceus  Mammalia  Primates
# 906    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 907    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 908    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 909    Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
#
#               Family        Genus  Year App.    ICUN Status Importer Exporter  \
# ...

# %%
monkeys1320.sum()
# Out:
# Common Name                   Green monkeyGreen monkeyCrab-eating macaqueCra...
# Taxon                         Chlorocebus sabaeusChlorocebus sabaeusMacaca f...
# Class                         MammaliaMammaliaMammaliaMammaliaMammaliaMammal...
# Order                         PrimatesPrimatesPrimatesPrimatesPrimatesPrimat...
# Family                        CercopithecidaeCercopithecidaeCercopithecidaeC...
# Genus                         ChlorocebusChlorocebusMacacaMacacaMacacaMacaca...
# Year                                                                     163258
# App.                          IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII...
# ICUN Status                   Least ConcernLeast ConcernVulnerableVulnerable...
# Importer                      USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Exporter                      BBBBCNCNCNCNKHMUMUMUVNCACACNCNJPDEZABBCKCNCNKH...
# Importer reported quantity                                                70579
# ...

# %%
## list number of macaques
filter1 = monkeys["Genus"] == "Macaca"
monkeys[filter1]
macaques = monkeys[filter1]
macaques
# Out:
#              Common Name                Taxon     Class     Order  \
# 6         Rhesus macaque       Macaca mulatta  Mammalia  Primates
# 21              Macaques          Macaca spp.  Mammalia  Primates
# 22   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 23   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 24      Japanese macaque       Macaca fuscata  Mammalia  Primates
# ..                   ...                  ...       ...       ...
# 904       Rhesus macaque       Macaca mulatta  Mammalia  Primates
# 906  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 907  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 908  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 909  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
#
#               Family   Genus  Year App.    ICUN Status Importer Exporter  \
# 6    Cercopithecidae  Macaca  1978   II  Least Concern       US       CA
# ...

# %%
macaques.sum()
# Out:
# Common Name                   Rhesus macaqueMacaquesCrab-eating macaqueCrab-...
# Taxon                         Macaca mulattaMacaca spp.Macaca fascicularisMa...
# Class                         MammaliaMammaliaMammaliaMammaliaMammaliaMammal...
# Order                         PrimatesPrimatesPrimatesPrimatesPrimatesPrimat...
# Family                        CercopithecidaeCercopithecidaeCercopithecidaeC...
# Genus                         MacacaMacacaMacacaMacacaMacacaMacacaMacacaMaca...
# Year                                                                     876411
# App.                          IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII...
# Importer                      USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Exporter                      CAMYIDMYCACABDCACAMYCAIDCACAGBIDPHCACNJPIDCADE...
# Importer reported quantity                                               212426
# Exporter reported quantity                                               166413
# ...

# %%
## Calculate percentage of macaques to all monkeys between 1975-2021

(212426/220725)*100
# Out:
# 96.24011779363461

# %%
## List number of crab-eating macaques between 195-2021

filter1 = monkeys["Common Name"] == "Crab-eating macaque"

crab = monkeys[filter1] 
crab
# Out:
#              Common Name                Taxon     Class     Order  \
# 22   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 23   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 49   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 60   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 61   Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# ..                   ...                  ...       ...       ...
# 901  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 906  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 907  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 908  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 909  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
#
#               Family   Genus  Year App. ICUN Status Importer Exporter Origin  \
# 22   Cercopithecidae  Macaca  1979   II  Vulnerable       US       ID    NaN
# ...

# %%
# Out:
#   File "<ipython-input-29-d4380d58f9f8>", line 1
#     DataFrame.dropna(axis=0, how=’any’, thresh=None, subset=None, inplace=False)
#                                      ^
# SyntaxError: invalid character in identifier

# %%
crab.sum()
# Out:
# Common Name                   Crab-eating macaqueCrab-eating macaqueCrab-eat...
# Taxon                         Macaca fascicularisMacaca fascicularisMacaca f...
# Class                         MammaliaMammaliaMammaliaMammaliaMammaliaMammal...
# Order                         PrimatesPrimatesPrimatesPrimatesPrimatesPrimat...
# Family                        CercopithecidaeCercopithecidaeCercopithecidaeC...
# Genus                         MacacaMacacaMacacaMacacaMacacaMacacaMacacaMaca...
# Year                                                                     620682
# App.                          IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII...
# ICUN Status                   VulnerableVulnerableVulnerableVulnerableVulner...
# Importer                      USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Exporter                      IDMYIDGBIDPHCADEIDJPCACAIDMYMYPHDEDEDEIDMYMYPH...
# Importer reported quantity                                               196915
# ...

# %%
## isolate years for macaques:

filter1 = crab["Year"] >= 2013
filter2 = crab["Year"] <= 2021

## Filter it

crab[filter1 & filter2]
crab1320 = crab[filter1 & filter2]
crab[filter1 & filter2]
# Out:
#              Common Name                Taxon     Class     Order  \
# 831  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 832  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 833  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 834  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 835  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 836  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 837  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 838  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 839  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 848  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 849  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 850  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# 851  Crab-eating macaque  Macaca fascicularis  Mammalia  Primates
# ...

# %%
crab1320.sum()
# Out:
# Common Name                   Crab-eating macaqueCrab-eating macaqueCrab-eat...
# Taxon                         Macaca fascicularisMacaca fascicularisMacaca f...
# Class                         MammaliaMammaliaMammaliaMammaliaMammaliaMammal...
# Order                         PrimatesPrimatesPrimatesPrimatesPrimatesPrimat...
# Family                        CercopithecidaeCercopithecidaeCercopithecidaeC...
# Genus                         MacacaMacacaMacacaMacacaMacacaMacacaMacacaMaca...
# Year                                                                      96743
# App.                          IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII...
# ICUN Status                   VulnerableVulnerableVulnerableVulnerableVulner...
# Importer                      USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Exporter                      CNCNCNCNKHMUMUMUVNCKCNCNKHMUMUMUVNVNCNKRMUMUTH...
# Importer reported quantity                                                65086
# ...

# %%
## percent of monkeys between 1975-2021 that are crab-eating macaques

(196915/220725)*100
# Out:
# 89.2128213840752

# %%
## percent of monkeys between 2013-2021 that are crab-eating macaques
(65086/70579)*100
# Out:
# 92.21723175448788

# %%
df['Exporter'].value_counts()
# Out:
# CA    119
# PE    108
# MU     83
# CN     82
# ID     79
# GB     61
# PH     34
# KE     30
# KN     28
# DE     28
# MG     25
# VN     23
# BB     20
# ZA     15
# JP     13
# FR     12
# BR     12
# MY     11
# ET     10
# GY     10
# NL      8
# AR      8
# KH      8
# IL      7
# RU      7
# SE      6
# MM      5
# TH      4
# CH      4
# CO      4
# HK      4
# BE      3
# GT      3
# SU      3
# GF      2
# KR      2
# CR      2
# TZ      2
# LR      2
# NI      2
# TG      2
# XX      2
# BO      2
# AU      2
# US      1
# PA      1
# VE      1
# CK      1
# SO      1
# IT      1
# ES      1
# JE      1
# SR      1
# KM      1
# BM      1
# BD      1
# MX      1
# Name: Exporter, dtype: int64

# %%
df['Year'].value_counts(ascending = True)
# Out:
# 1976     1
# 1977     1
# 2019     5
# 1978     5
# 2015     8
# 2017    10
# 2018    10
# 2014    15
# 2013    15
# 2010    15
# 1980    16
# 2011    17
# 1981    17
# 1996    17
# 2012    17
# 1997    18
# 2016    18
# 1992    19
# 2009    19
# 1990    19
# 1998    19
# 1994    21
# 1989    21
# 1999    22
# 1993    22
# 1988    23
# 1982    24
# 1991    24
# 2007    25
# 2008    25
# 1995    25
# 2006    26
# 1983    27
# 2004    28
# 2005    28
# 1984    28
# 1987    29
# 2003    30
# 1979    31
# 2000    32
# 1986    33
# 1985    33
# 2001    34
# 2002    38
# Name: Year, dtype: int64
